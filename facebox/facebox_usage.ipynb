# %% [markdown]
# Run facebox with:
# ```
# sudo docker run -p 8080:8080 -e "MB_KEY=$MB_KEY" machinebox/facebox_noavx
# ```

# %%
import os.path
import requests
import shutil

from PIL import Image
import io
from facebox import Facebox, valid_image_file
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pathlib import Path
root_dir = Path(os.getcwd()).parent

# %% [markdown]
# Test image to process

# %%
file_path = os.path.join(root_dir, 'resources/thebeatles.jpg')

#file_path = 'README.md' # an invalid image

if valid_image_file(file_path):
    img = plt.imread(file_path)
    plt.imshow(img);

# %%
root_dir
# Out:
# PosixPath('/Users/robincole/Documents/Github/sdk-python')

# %%
facebox = Facebox() # ip_address='localhosty'

# %%
facebox.process_file(file_path)
# Out:
# Processed /Users/robincole/Documents/Github/sdk-python/resources/thebeatles.jpg and found 12 faces

# %%
facebox.matched_faces
# Out:
# {'total_faces': 12,
#  'matched_faces': {'George_Harrison': 69.83,
#   'Paul_McCartney': 77.52,
#   'John_Lennon': 64.59,
#   'Ringo_Starr': 71.33},
#  'total_matched_faces': 4}

# %%
facebox.faces
# Out:
# [{'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 124, 'left': 636, 'width': 52, 'height': 52}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 129, 'left': 246, 'width': 62, 'height': 62}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 164, 'left': 711, 'width': 52, 'height': 52}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 118, 'left': 106, 'width': 52, 'height': 52}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 118, 'left': 549, 'width': 43, 'height': 43}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 166, 'left': 866, 'width': 43, 'height': 43}},
#  {'name': 'George_Harrison',
#   'image_id': 'george2.jpg',
#   'confidence': 69.83,
#   'matched': True,
#   'bounding_box': {'top': 253, 'left': 563, 'width': 63, 'height': 62}},
#  {'name': 'Paul_McCartney',
#   'image_id': 'paul3.jpg',
#   'confidence': 77.52,
#   'matched': True,
#   'bounding_box': {'top': 246, 'left': 287, 'width': 74, 'height': 74}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 204, 'left': 55, 'width': 74, 'height': 75}},
#  {'name': 'John_Lennon',
#   'image_id': 'john3.jpg',
#   'confidence': 64.59,
#   'matched': True,
#   'bounding_box': {'top': 262, 'left': 63, 'width': 74, 'height': 75}},
#  {'name': 'Ringo_Starr',
#   'image_id': 'ringo1.jpg',
#   'confidence': 71.33,
#   'matched': True,
#   'bounding_box': {'top': 322, 'left': 709, 'width': 62, 'height': 62}},
#  {'name': None,
#   'image_id': None,
#   'confidence': 0.0,
#   'matched': False,
#   'bounding_box': {'top': 78, 'left': 803, 'width': 52, 'height': 52}}]

# %% [markdown]
# ## Teach
# Lets teach Facebox

# %%
clark_path = os.path.join(root_dir, 'resources/clark_kent.jpg')
#file_path = 'README.md' # an invalid image

if valid_image_file(clark_path):
    img = plt.imread(clark_path)
    plt.imshow(img);

# %%
facebox.teach('superman', clark_path)
# Out:
# Taught face superman with file /Users/robincole/Documents/Github/sdk-python/resources/clark_kent.jpg

# %%
superman_path = os.path.join(root_dir, 'resources/superman.jpg')
#file_path = 'README.md' # an invalid image

if valid_image_file(superman_path):
    img = plt.imread(superman_path)
    plt.imshow(img);

# %%
facebox.process_file(superman_path)
# Out:
# Processed /Users/robincole/Documents/Github/sdk-python/resources/superman.jpg and found 1 faces

# %%
facebox.matched_faces
# Out:
# {'total_faces': 1,
#  'matched_faces': {'superman': 55.63},
#  'total_matched_faces': 1}

# %% [markdown]
# ## Get & Post state

# %%
facebox.get_state()
# Out:
# Downloaded state file : state.facebox

# %%
facebox.post_state()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-bb453ebf918d> in <module>()
# ----> 1 facebox.post_state()
#
# ~/Documents/Github/sdk-python/facebox/facebox.py in post_state(self)
#     163             self._url_state,
#     164             files=file,
# --> 165             **kwargs
#     166         )
#     167         if self._print_info:
#
# NameError: name 'kwargs' is not defined

# %%
os.remove('state.facebox')
